# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import numpy as np 

from datetime import datetime
from citipy import citipy

# Import the API key.
from config import g_key
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes 

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.

cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:20], 'Generate', len(cities))
# Out:
# ['taburao', 'komagane', 'severo-kurilsk', 'ushuaia', 'pathein', 'east london', 'punta arenas', 'hermanus', 'yellowknife', 'talcahuano', 'mataura', 'tuatapere', 'taolanaro', 'barrow', 'itarema', 'half moon bay', 'zhigansk', 'zapolyarnyy', 'lorengau', 'bredasdorp'] Generate 765

# %%
#Perform an API call with the OpenWeatherMap

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c7a68ad3356346215a0eaa8f662eb55

# %%
# Retrieve the following information from the API call:
    # Latitude and longitude
    # Maximum temperature
    # Percent humidity
    # Percent cloudiness
    # Wind speed
    # Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taburao
# City not found. Skipping...
# Processing Record 2 of Set 1 | komagane
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | pathein
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | talcahuano
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | tuatapere
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | itarema
# Processing Record 16 of Set 1 | half moon bay
# Processing Record 17 of Set 1 | zhigansk
# Processing Record 18 of Set 1 | zapolyarnyy
# Processing Record 19 of Set 1 | lorengau
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | santa rosa
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | vostok
# Processing Record 25 of Set 1 | korla
# Processing Record 26 of Set 1 | umm ruwabah
# City not found. Skipping...
# Processing Record 27 of Set 1 | arauca
# Processing Record 28 of Set 1 | colares
# Processing Record 29 of Set 1 | cape coral
# Processing Record 30 of Set 1 | komsomolskiy
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | makinsk
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | kaeo
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | altay
# Processing Record 39 of Set 1 | gari
# Processing Record 40 of Set 1 | jieshi
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | kodiak
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | neryungri
# Processing Record 48 of Set 1 | abha
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | port blair
# Processing Record 2 of Set 2 | vestmannaeyjar
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | arzgir
# Processing Record 6 of Set 2 | avera
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | kerman
# Processing Record 12 of Set 2 | vila velha
# Processing Record 13 of Set 2 | coahuayana
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | port macquarie
# Processing Record 16 of Set 2 | laranjeiras do sul
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | yagodnoye
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | videbaek
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | tomball
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | mokhsogollokh
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | summerville
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | palmer
# Processing Record 32 of Set 2 | torbay
# Processing Record 33 of Set 2 | bocas del toro
# Processing Record 34 of Set 2 | yar-sale
# Processing Record 35 of Set 2 | port-gentil
# Processing Record 36 of Set 2 | saint-augustin
# Processing Record 37 of Set 2 | ken caryl
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | sobolevo
# Processing Record 40 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 2 | kavieng
# Processing Record 42 of Set 2 | krugersdorp
# Processing Record 43 of Set 2 | ilulissat
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | pangai
# Processing Record 47 of Set 2 | chernyshevskiy
# Processing Record 48 of Set 2 | esperance
# Processing Record 49 of Set 2 | hofn
# Processing Record 50 of Set 2 | vaini
# Processing Record 1 of Set 3 | pontes e lacerda
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | yulara
# Processing Record 4 of Set 3 | kruisfontein
# Processing Record 5 of Set 3 | monkey hill
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | duz
# City not found. Skipping...
# Processing Record 8 of Set 3 | bukachacha
# Processing Record 9 of Set 3 | fergus falls
# Processing Record 10 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | suao
# City not found. Skipping...
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | mount gambier
# Processing Record 14 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 3 | nyurba
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | mahebourg
# Processing Record 18 of Set 3 | praia da vitoria
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | albany
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | tiksi
# Processing Record 25 of Set 3 | vila franca do campo
# Processing Record 26 of Set 3 | luderitz
# Processing Record 27 of Set 3 | wenling
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | prieska
# Processing Record 30 of Set 3 | erzin
# Processing Record 31 of Set 3 | mirabad
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | baykit
# Processing Record 34 of Set 3 | udachnyy
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 3 | harper
# Processing Record 38 of Set 3 | hamilton
# Processing Record 39 of Set 3 | grindavik
# Processing Record 40 of Set 3 | bluefields
# Processing Record 41 of Set 3 | laguna
# Processing Record 42 of Set 3 | san quintin
# Processing Record 43 of Set 3 | paamiut
# Processing Record 44 of Set 3 | adrar
# Processing Record 45 of Set 3 | maragogi
# Processing Record 46 of Set 3 | sosnovo-ozerskoye
# Processing Record 47 of Set 3 | troitskoye
# Processing Record 48 of Set 3 | taree
# Processing Record 49 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 3 | zhuhai
# Processing Record 1 of Set 4 | vila
# Processing Record 2 of Set 4 | shubarkuduk
# Processing Record 3 of Set 4 | broken hill
# Processing Record 4 of Set 4 | lompoc
# Processing Record 5 of Set 4 | gabu
# Processing Record 6 of Set 4 | aosta
# Processing Record 7 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 4 | sarahan
# Processing Record 10 of Set 4 | santiago del estero
# Processing Record 11 of Set 4 | redmond
# Processing Record 12 of Set 4 | airai
# Processing Record 13 of Set 4 | jiayuguan
# Processing Record 14 of Set 4 | cap-aux-meules
# Processing Record 15 of Set 4 | samarai
# Processing Record 16 of Set 4 | shuangyang
# Processing Record 17 of Set 4 | bandarbeyla
# Processing Record 18 of Set 4 | lavrentiya
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | abinsk
# Processing Record 21 of Set 4 | nokaneng
# Processing Record 22 of Set 4 | muisne
# Processing Record 23 of Set 4 | portland
# Processing Record 24 of Set 4 | wahpeton
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | lubaczow
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | ileza
# Processing Record 29 of Set 4 | wajima
# Processing Record 30 of Set 4 | elko
# Processing Record 31 of Set 4 | kralendijk
# Processing Record 32 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 4 | diego de almagro
# Processing Record 34 of Set 4 | kanodar
# Processing Record 35 of Set 4 | lebu
# Processing Record 36 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 4 | muyezerskiy
# Processing Record 38 of Set 4 | honiara
# Processing Record 39 of Set 4 | thompson
# Processing Record 40 of Set 4 | aban
# Processing Record 41 of Set 4 | flinders
# Processing Record 42 of Set 4 | beloit
# Processing Record 43 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 4 | uni
# Processing Record 45 of Set 4 | makakilo city
# Processing Record 46 of Set 4 | karabulak
# Processing Record 47 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 4 | sal rei
# Processing Record 49 of Set 4 | arraial do cabo
# Processing Record 50 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 5 | oktyabrskoye
# Processing Record 2 of Set 5 | kuvshinovo
# Processing Record 3 of Set 5 | fare
# Processing Record 4 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 5 | datong
# Processing Record 6 of Set 5 | hasaki
# Processing Record 7 of Set 5 | shimoda
# Processing Record 8 of Set 5 | zyryanka
# Processing Record 9 of Set 5 | fort nelson
# Processing Record 10 of Set 5 | ilesha
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | saint george
# Processing Record 13 of Set 5 | kuntaur
# Processing Record 14 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 15 of Set 5 | khatanga
# Processing Record 16 of Set 5 | sao miguel
# Processing Record 17 of Set 5 | bani walid
# Processing Record 18 of Set 5 | bulungu
# Processing Record 19 of Set 5 | kitui
# Processing Record 20 of Set 5 | phan thiet
# Processing Record 21 of Set 5 | kuusamo
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | gympie
# Processing Record 24 of Set 5 | urucara
# Processing Record 25 of Set 5 | liverpool
# Processing Record 26 of Set 5 | el alto
# Processing Record 27 of Set 5 | egvekinot
# Processing Record 28 of Set 5 | kamenka
# Processing Record 29 of Set 5 | turukhansk
# Processing Record 30 of Set 5 | najran
# Processing Record 31 of Set 5 | morro bay
# Processing Record 32 of Set 5 | chapais
# Processing Record 33 of Set 5 | vasai
# Processing Record 34 of Set 5 | brody
# Processing Record 35 of Set 5 | faya
# Processing Record 36 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 5 | beloha
# Processing Record 38 of Set 5 | ancud
# Processing Record 39 of Set 5 | sibolga
# Processing Record 40 of Set 5 | port hedland
# Processing Record 41 of Set 5 | atar
# Processing Record 42 of Set 5 | nawabganj
# Processing Record 43 of Set 5 | beringovskiy
# Processing Record 44 of Set 5 | honningsvag
# Processing Record 45 of Set 5 | hovd
# Processing Record 46 of Set 5 | ahuimanu
# Processing Record 47 of Set 5 | grants pass
# Processing Record 48 of Set 5 | ebolowa
# Processing Record 49 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 50 of Set 5 | jalu
# Processing Record 1 of Set 6 | mao
# Processing Record 2 of Set 6 | mitsamiouli
# Processing Record 3 of Set 6 | sao jose da coroa grande
# Processing Record 4 of Set 6 | assiniboia
# Processing Record 5 of Set 6 | sao filipe
# Processing Record 6 of Set 6 | katsuura
# Processing Record 7 of Set 6 | new norfolk
# Processing Record 8 of Set 6 | careiro da varzea
# Processing Record 9 of Set 6 | vestmanna
# Processing Record 10 of Set 6 | la reforma
# Processing Record 11 of Set 6 | sebezh
# Processing Record 12 of Set 6 | saint-ambroise
# Processing Record 13 of Set 6 | marion
# Processing Record 14 of Set 6 | maumere
# Processing Record 15 of Set 6 | ucluelet
# Processing Record 16 of Set 6 | lamu
# Processing Record 17 of Set 6 | acaponeta
# Processing Record 18 of Set 6 | penzance
# Processing Record 19 of Set 6 | batagay
# Processing Record 20 of Set 6 | marawi
# Processing Record 21 of Set 6 | campbellsville
# Processing Record 22 of Set 6 | faanui
# Processing Record 23 of Set 6 | auki
# Processing Record 24 of Set 6 | yumen
# Processing Record 25 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 6 | rio grande
# Processing Record 27 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 6 | navalmoral de la mata
# Processing Record 29 of Set 6 | flin flon
# Processing Record 30 of Set 6 | road town
# Processing Record 31 of Set 6 | sabha
# Processing Record 32 of Set 6 | armidale
# Processing Record 33 of Set 6 | banda aceh
# Processing Record 34 of Set 6 | saint-pierre
# Processing Record 35 of Set 6 | numan
# Processing Record 36 of Set 6 | lincoln
# Processing Record 37 of Set 6 | helong
# Processing Record 38 of Set 6 | sao joao da barra
# Processing Record 39 of Set 6 | kosonsoy
# Processing Record 40 of Set 6 | arlit
# Processing Record 41 of Set 6 | biltine
# Processing Record 42 of Set 6 | zhangjiakou
# Processing Record 43 of Set 6 | caravelas
# Processing Record 44 of Set 6 | salta
# Processing Record 45 of Set 6 | longyearbyen
# Processing Record 46 of Set 6 | veraval
# Processing Record 47 of Set 6 | saint anthony
# Processing Record 48 of Set 6 | bonavista
# Processing Record 49 of Set 6 | clyde river
# Processing Record 50 of Set 6 | bubaque
# Processing Record 1 of Set 7 | angoche
# Processing Record 2 of Set 7 | nome
# Processing Record 3 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | constitucion
# Processing Record 5 of Set 7 | talnakh
# Processing Record 6 of Set 7 | pravokumskoye
# Processing Record 7 of Set 7 | toyooka
# Processing Record 8 of Set 7 | poum
# Processing Record 9 of Set 7 | santiago
# Processing Record 10 of Set 7 | naze
# Processing Record 11 of Set 7 | banyo
# Processing Record 12 of Set 7 | naryshkino
# Processing Record 13 of Set 7 | hostotipaquillo
# Processing Record 14 of Set 7 | kenai
# Processing Record 15 of Set 7 | okhotsk
# Processing Record 16 of Set 7 | miranorte
# City not found. Skipping...
# Processing Record 17 of Set 7 | gusevskiy
# Processing Record 18 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 7 | souris
# Processing Record 20 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 7 | nakamura
# Processing Record 22 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 23 of Set 7 | sibu
# Processing Record 24 of Set 7 | karratha
# Processing Record 25 of Set 7 | puerto escondido
# Processing Record 26 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 7 | morant bay
# Processing Record 28 of Set 7 | san buenaventura
# Processing Record 29 of Set 7 | reconquista
# Processing Record 30 of Set 7 | dubrovnik
# Processing Record 31 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 7 | pachora
# Processing Record 33 of Set 7 | lagoa
# Processing Record 34 of Set 7 | beterou
# Processing Record 35 of Set 7 | port elizabeth
# Processing Record 36 of Set 7 | huatusco
# Processing Record 37 of Set 7 | new cumnock
# Processing Record 38 of Set 7 | mecca
# Processing Record 39 of Set 7 | kosai
# Processing Record 40 of Set 7 | gannan
# Processing Record 41 of Set 7 | buchanan
# Processing Record 42 of Set 7 | vasto
# Processing Record 43 of Set 7 | kem
# Processing Record 44 of Set 7 | olinda
# Processing Record 45 of Set 7 | sur
# Processing Record 46 of Set 7 | guerrero negro
# Processing Record 47 of Set 7 | palmas bellas
# Processing Record 48 of Set 7 | starkville
# Processing Record 49 of Set 7 | ostrovnoy
# Processing Record 50 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 1 of Set 8 | bay village
# Processing Record 2 of Set 8 | bontang
# Processing Record 3 of Set 8 | codrington
# Processing Record 4 of Set 8 | porto murtinho
# Processing Record 5 of Set 8 | matehuala
# Processing Record 6 of Set 8 | saldanha
# Processing Record 7 of Set 8 | sioux lookout
# Processing Record 8 of Set 8 | hambantota
# Processing Record 9 of Set 8 | holme
# Processing Record 10 of Set 8 | boo
# Processing Record 11 of Set 8 | xingyi
# Processing Record 12 of Set 8 | kawanoe
# Processing Record 13 of Set 8 | lichuan
# Processing Record 14 of Set 8 | mnogovershinnyy
# Processing Record 15 of Set 8 | tefe
# Processing Record 16 of Set 8 | campoverde
# Processing Record 17 of Set 8 | dzilam gonzalez
# Processing Record 18 of Set 8 | esik
# Processing Record 19 of Set 8 | nanakuli
# Processing Record 20 of Set 8 | pangoa
# Processing Record 21 of Set 8 | aljezur
# Processing Record 22 of Set 8 | caraballeda
# Processing Record 23 of Set 8 | anlu
# Processing Record 24 of Set 8 | durazno
# Processing Record 25 of Set 8 | mar del plata
# Processing Record 26 of Set 8 | bowen
# Processing Record 27 of Set 8 | kiama
# Processing Record 28 of Set 8 | inirida
# Processing Record 29 of Set 8 | jaitaran
# Processing Record 30 of Set 8 | huilong
# Processing Record 31 of Set 8 | saint-louis
# Processing Record 32 of Set 8 | vilyuysk
# Processing Record 33 of Set 8 | svetlogorsk
# Processing Record 34 of Set 8 | broome
# Processing Record 35 of Set 8 | asyut
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | saint-francois
# Processing Record 38 of Set 8 | kudahuvadhoo
# Processing Record 39 of Set 8 | tezu
# Processing Record 40 of Set 8 | kingaroy
# Processing Record 41 of Set 8 | boa vista
# Processing Record 42 of Set 8 | pisco
# Processing Record 43 of Set 8 | lazaro cardenas
# Processing Record 44 of Set 8 | nouadhibou
# Processing Record 45 of Set 8 | vardo
# Processing Record 46 of Set 8 | mazagao
# Processing Record 47 of Set 8 | cervo
# Processing Record 48 of Set 8 | oistins
# Processing Record 49 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 8 | umm lajj
# Processing Record 1 of Set 9 | haines junction
# Processing Record 2 of Set 9 | barabash
# Processing Record 3 of Set 9 | ponnani
# Processing Record 4 of Set 9 | chippewa falls
# Processing Record 5 of Set 9 | victoria point
# Processing Record 6 of Set 9 | nhamunda
# Processing Record 7 of Set 9 | hengyang
# Processing Record 8 of Set 9 | orlik
# Processing Record 9 of Set 9 | elizabeth city
# Processing Record 10 of Set 9 | camacha
# Processing Record 11 of Set 9 | mackay
# Processing Record 12 of Set 9 | sitka
# Processing Record 13 of Set 9 | iracoubo
# Processing Record 14 of Set 9 | namatanai
# Processing Record 15 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 9 | vanimo
# Processing Record 17 of Set 9 | aksay
# Processing Record 18 of Set 9 | riaba
# City not found. Skipping...
# Processing Record 19 of Set 9 | tiznit
# Processing Record 20 of Set 9 | sfantu gheorghe
# Processing Record 21 of Set 9 | burgeo
# Processing Record 22 of Set 9 | san carlos de bariloche
# Processing Record 23 of Set 9 | abu dhabi
# Processing Record 24 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 9 | gazanjyk
# Processing Record 26 of Set 9 | haapiti
# Processing Record 27 of Set 9 | houma
# Processing Record 28 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 29 of Set 9 | tulsipur
# Processing Record 30 of Set 9 | omsukchan
# Processing Record 31 of Set 9 | san benito abad
# Processing Record 32 of Set 9 | tocopilla
# Processing Record 33 of Set 9 | dakar
# Processing Record 34 of Set 9 | halifax
# Processing Record 35 of Set 9 | kamennomostskiy
# Processing Record 36 of Set 9 | alice springs
# Processing Record 37 of Set 9 | kahului
# Processing Record 38 of Set 9 | medicine hat
# Processing Record 39 of Set 9 | illela
# Processing Record 40 of Set 9 | dajal
# Processing Record 41 of Set 9 | hirara
# Processing Record 42 of Set 9 | hinton
# Processing Record 43 of Set 9 | erie
# Processing Record 44 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 45 of Set 9 | worthington
# Processing Record 46 of Set 9 | loharu
# Processing Record 47 of Set 9 | bellevue
# Processing Record 48 of Set 9 | portree
# Processing Record 49 of Set 9 | santa cruz cabralia
# Processing Record 50 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 10 | muros
# Processing Record 2 of Set 10 | okha
# Processing Record 3 of Set 10 | bolshaya vishera
# City not found. Skipping...
# Processing Record 4 of Set 10 | leh
# Processing Record 5 of Set 10 | fairbanks
# Processing Record 6 of Set 10 | junction city
# Processing Record 7 of Set 10 | sergokala
# Processing Record 8 of Set 10 | wau
# Processing Record 9 of Set 10 | maniitsoq
# Processing Record 10 of Set 10 | port hardy
# Processing Record 11 of Set 10 | acapulco
# Processing Record 12 of Set 10 | ust-nera
# Processing Record 13 of Set 10 | klaksvik
# Processing Record 14 of Set 10 | mizdah
# Processing Record 15 of Set 10 | puerto suarez
# Processing Record 16 of Set 10 | kamaishi
# Processing Record 17 of Set 10 | sorland
# Processing Record 18 of Set 10 | svetlyy
# Processing Record 19 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 10 | singaraja
# Processing Record 21 of Set 10 | awbari
# Processing Record 22 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 23 of Set 10 | president roxas
# Processing Record 24 of Set 10 | kremenchuk
# Processing Record 25 of Set 10 | seydi
# Processing Record 26 of Set 10 | atambua
# Processing Record 27 of Set 10 | bonfim
# Processing Record 28 of Set 10 | kasama
# Processing Record 29 of Set 10 | da nang
# Processing Record 30 of Set 10 | tenenkou
# Processing Record 31 of Set 10 | buraydah
# Processing Record 32 of Set 10 | mount isa
# Processing Record 33 of Set 10 | ilfracombe
# Processing Record 34 of Set 10 | sajanan
# Processing Record 35 of Set 10 | avenal
# Processing Record 36 of Set 10 | kang
# Processing Record 37 of Set 10 | tallahassee
# Processing Record 38 of Set 10 | richards bay
# Processing Record 39 of Set 10 | praxedis guerrero
# Processing Record 40 of Set 10 | husavik
# Processing Record 41 of Set 10 | aktas
# Processing Record 42 of Set 10 | coquimbo
# Processing Record 43 of Set 10 | vitim
# Processing Record 44 of Set 10 | pemangkat
# Processing Record 45 of Set 10 | krutinka
# Processing Record 46 of Set 10 | miraflores
# Processing Record 47 of Set 10 | bermejo
# Processing Record 48 of Set 10 | wladyslawowo
# Processing Record 49 of Set 10 | margate
# Processing Record 50 of Set 10 | plouzane
# Processing Record 1 of Set 11 | bengkulu
# Processing Record 2 of Set 11 | ust-kut
# Processing Record 3 of Set 11 | jiangyou
# Processing Record 4 of Set 11 | salinas
# Processing Record 5 of Set 11 | cayenne
# Processing Record 6 of Set 11 | salalah
# Processing Record 7 of Set 11 | kysyl-syr
# Processing Record 8 of Set 11 | cabedelo
# Processing Record 9 of Set 11 | inhambane
# Processing Record 10 of Set 11 | paharpur
# Processing Record 11 of Set 11 | krasnoarmeyskoye
# Processing Record 12 of Set 11 | neka
# Processing Record 13 of Set 11 | ponta pora
# Processing Record 14 of Set 11 | aitape
# Processing Record 15 of Set 11 | kirkuk
# Processing Record 16 of Set 11 | wanning
# Processing Record 17 of Set 11 | olga
# Processing Record 18 of Set 11 | ugoofaaru
# Processing Record 19 of Set 11 | klichka
# Processing Record 20 of Set 11 | manali
# Processing Record 21 of Set 11 | pochutla
# Processing Record 22 of Set 11 | bauta
# Processing Record 23 of Set 11 | mount vernon
# Processing Record 24 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 11 | chimore
# Processing Record 26 of Set 11 | dashitou
# Processing Record 27 of Set 11 | bend
# Processing Record 28 of Set 11 | berlevag
# Processing Record 29 of Set 11 | rundu
# Processing Record 30 of Set 11 | yekaterinovka
# Processing Record 31 of Set 11 | waihi beach
# Processing Record 32 of Set 11 | puerto narino
# Processing Record 33 of Set 11 | bell ville
# Processing Record 34 of Set 11 | joutseno
# Processing Record 35 of Set 11 | kutoarjo
# Processing Record 36 of Set 11 | vyartsilya
# Processing Record 37 of Set 11 | pagman
# City not found. Skipping...
# Processing Record 38 of Set 11 | baker city
# Processing Record 39 of Set 11 | zatoka
# Processing Record 40 of Set 11 | ayr
# Processing Record 41 of Set 11 | cardston
# Processing Record 42 of Set 11 | requena
# Processing Record 43 of Set 11 | roald
# Processing Record 44 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 45 of Set 11 | soma
# Processing Record 46 of Set 11 | rodrigues alves
# Processing Record 47 of Set 11 | araouane
# Processing Record 48 of Set 11 | oktyabrskiy
# Processing Record 49 of Set 11 | ambulu
# Processing Record 50 of Set 11 | turan
# Processing Record 1 of Set 12 | thinadhoo
# Processing Record 2 of Set 12 | solnechnyy
# Processing Record 3 of Set 12 | tura
# Processing Record 4 of Set 12 | piacabucu
# Processing Record 5 of Set 12 | gat
# Processing Record 6 of Set 12 | talmenka
# Processing Record 7 of Set 12 | alofi
# Processing Record 8 of Set 12 | jiwani
# Processing Record 9 of Set 12 | puerto leguizamo
# Processing Record 10 of Set 12 | blind river
# Processing Record 11 of Set 12 | kokoda
# Processing Record 12 of Set 12 | chake chake
# Processing Record 13 of Set 12 | luganville
# Processing Record 14 of Set 12 | palembang
# Processing Record 15 of Set 12 | martaban
# Processing Record 16 of Set 12 | turka
# Processing Record 17 of Set 12 | les cayes
# Processing Record 18 of Set 12 | birjand
# Processing Record 19 of Set 12 | constantine
# Processing Record 20 of Set 12 | zadar
# Processing Record 21 of Set 12 | porto novo
# Processing Record 22 of Set 12 | bakurianis andeziti
# Processing Record 23 of Set 12 | tuensang
# Processing Record 24 of Set 12 | ormara
# Processing Record 25 of Set 12 | jena
# Processing Record 26 of Set 12 | dalbandin
# Processing Record 27 of Set 12 | douglas
# Processing Record 28 of Set 12 | munster
# Processing Record 29 of Set 12 | naples
# Processing Record 30 of Set 12 | kokopo
# Processing Record 31 of Set 12 | pierre
# Processing Record 32 of Set 12 | araguari
# Processing Record 33 of Set 12 | tibagi
# Processing Record 34 of Set 12 | garmsar
# Processing Record 35 of Set 12 | granadilla de abona
# Processing Record 36 of Set 12 | tilichiki
# Processing Record 37 of Set 12 | kotelnich
# Processing Record 38 of Set 12 | mamallapuram
# Processing Record 39 of Set 12 | ust-tsilma
# Processing Record 40 of Set 12 | tutoia
# Processing Record 41 of Set 12 | eyl
# Processing Record 42 of Set 12 | uruzgan
# Processing Record 43 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 12 | brownsville
# Processing Record 45 of Set 12 | guaruja
# Processing Record 46 of Set 12 | narsaq
# Processing Record 47 of Set 12 | baihar
# Processing Record 48 of Set 12 | khasan
# Processing Record 49 of Set 12 | high level
# Processing Record 50 of Set 12 | tsiroanomandidy
# Processing Record 1 of Set 13 | aberdeen
# Processing Record 2 of Set 13 | barcelos
# Processing Record 3 of Set 13 | cocorna
# Processing Record 4 of Set 13 | greytown
# Processing Record 5 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 6 of Set 13 | namibe
# Processing Record 7 of Set 13 | ust-kuyga
# Processing Record 8 of Set 13 | vila do maio
# Processing Record 9 of Set 13 | goderich
# Processing Record 10 of Set 13 | uruana
# Processing Record 11 of Set 13 | cuervos
# Processing Record 12 of Set 13 | nemuro
# Processing Record 13 of Set 13 | porto santo
# Processing Record 14 of Set 13 | paita
# Processing Record 15 of Set 13 | ulladulla
# Processing Record 16 of Set 13 | martapura
# Processing Record 17 of Set 13 | lasa
# Processing Record 18 of Set 13 | ambilobe
# Processing Record 19 of Set 13 | dingle
# Processing Record 20 of Set 13 | booue
# Processing Record 21 of Set 13 | burnie
# Processing Record 22 of Set 13 | khlevnoye
# Processing Record 23 of Set 13 | canico
# Processing Record 24 of Set 13 | belaya gora
# Processing Record 25 of Set 13 | seddon
# Processing Record 26 of Set 13 | laguna de duero
# Processing Record 27 of Set 13 | kununurra
# Processing Record 28 of Set 13 | grand gaube
# Processing Record 29 of Set 13 | nova olimpia
# Processing Record 30 of Set 13 | maarianhamina
# Processing Record 31 of Set 13 | ihosy
# Processing Record 32 of Set 13 | gerash
# Processing Record 33 of Set 13 | peniche
# Processing Record 34 of Set 13 | aparecida
# Processing Record 35 of Set 13 | xining
# Processing Record 36 of Set 13 | tamiahua
# Processing Record 37 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 38 of Set 13 | manokwari
# Processing Record 39 of Set 13 | brigantine
# Processing Record 40 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 41 of Set 13 | bartica
# Processing Record 42 of Set 13 | wanxian
# Processing Record 43 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 13 | san rafael
# Processing Record 45 of Set 13 | padang
# Processing Record 46 of Set 13 | plettenberg bay
# Processing Record 47 of Set 13 | usogorsk
# Processing Record 48 of Set 13 | san cristobal
# Processing Record 49 of Set 13 | urumqi
# Processing Record 50 of Set 13 | ampanihy
# Processing Record 1 of Set 14 | vao
# Processing Record 2 of Set 14 | juan lacaze
# Processing Record 3 of Set 14 | jimeta
# Processing Record 4 of Set 14 | neepawa
# Processing Record 5 of Set 14 | puerto ayacucho
# Processing Record 6 of Set 14 | russell
# Processing Record 7 of Set 14 | anito
# Processing Record 8 of Set 14 | rudnyy
# Processing Record 9 of Set 14 | kaposvar
# Processing Record 10 of Set 14 | chipinge
# Processing Record 11 of Set 14 | cedar city
# Processing Record 12 of Set 14 | binika
# Processing Record 13 of Set 14 | mishan
# Processing Record 14 of Set 14 | matay
# Processing Record 15 of Set 14 | liuzhou
# Processing Record 16 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 14 | sechura
# Processing Record 18 of Set 14 | khash
# Processing Record 19 of Set 14 | aswan
# Processing Record 20 of Set 14 | khandyga
# Processing Record 21 of Set 14 | te anau
# Processing Record 22 of Set 14 | colac
# Processing Record 23 of Set 14 | lardos
# Processing Record 24 of Set 14 | arequipa
# Processing Record 25 of Set 14 | tautira
# Processing Record 26 of Set 14 | mandali
# Processing Record 27 of Set 14 | emerald
# Processing Record 28 of Set 14 | verkhnevilyuysk
# Processing Record 29 of Set 14 | doha
# Processing Record 30 of Set 14 | raduzhnyy
# Processing Record 31 of Set 14 | san juan de uraba
# Processing Record 32 of Set 14 | molochnoye
# Processing Record 33 of Set 14 | kyzyl-suu
# Processing Record 34 of Set 14 | cartagena del chaira
# Processing Record 35 of Set 14 | gbarnga
# Processing Record 36 of Set 14 | anadyr
# Processing Record 37 of Set 14 | kalmunai
# Processing Record 38 of Set 14 | oranjemund
# Processing Record 39 of Set 14 | manacapuru
# Processing Record 40 of Set 14 | valley city
# Processing Record 41 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 14 | tinaquillo
# Processing Record 43 of Set 14 | san bernardo
# Processing Record 44 of Set 14 | bemidji
# Processing Record 45 of Set 14 | yuanping
# Processing Record 46 of Set 14 | jijiga
# Processing Record 47 of Set 14 | leningradskiy
# Processing Record 48 of Set 14 | tecoanapa
# Processing Record 49 of Set 14 | nuuk
# Processing Record 50 of Set 14 | kismayo
# Processing Record 1 of Set 15 | bondoukou
# Processing Record 2 of Set 15 | eureka
# Processing Record 3 of Set 15 | cockburn town
# Processing Record 4 of Set 15 | gurupa
# Processing Record 5 of Set 15 | tiarei
# Processing Record 6 of Set 15 | olafsvik
# Processing Record 7 of Set 15 | san jeronimo
# Processing Record 8 of Set 15 | linkou
# Processing Record 9 of Set 15 | tlahualilo
# City not found. Skipping...
# Processing Record 10 of Set 15 | hobyo
# Processing Record 11 of Set 15 | baleno
# Processing Record 12 of Set 15 | pitkyaranta
# Processing Record 13 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 15 | ahipara
# Processing Record 15 of Set 15 | teguldet
# Processing Record 16 of Set 15 | urusha
# Processing Record 17 of Set 15 | north bend
# Processing Record 18 of Set 15 | ikole
# City not found. Skipping...
# Processing Record 19 of Set 15 | moron
# Processing Record 20 of Set 15 | isakly
# Processing Record 21 of Set 15 | hami
# Processing Record 22 of Set 15 | bac lieu
# Processing Record 23 of Set 15 | wattegama
# Processing Record 24 of Set 15 | svetlaya
# Processing Record 25 of Set 15 | ismailia
# Processing Record 26 of Set 15 | port lincoln
# Processing Record 27 of Set 15 | trnava
# Processing Record 28 of Set 15 | touros
# Processing Record 29 of Set 15 | kincardine
# Processing Record 30 of Set 15 | balkanabat
# Processing Record 31 of Set 15 | tigil
# Processing Record 32 of Set 15 | ornskoldsvik
# Processing Record 33 of Set 15 | kargasok
# Processing Record 34 of Set 15 | bulgan
# Processing Record 35 of Set 15 | puri
# Processing Record 36 of Set 15 | fereydun kenar
# Processing Record 37 of Set 15 | chama
# Processing Record 38 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 15 | jefferson city
# Processing Record 40 of Set 15 | coihaique
# Processing Record 41 of Set 15 | cairns
# Processing Record 42 of Set 15 | hakkari
# Processing Record 43 of Set 15 | hervey bay
# Processing Record 44 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 15 | teya
# Processing Record 46 of Set 15 | banjar
# Processing Record 47 of Set 15 | pevek
# Processing Record 48 of Set 15 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 49 of Set 15 | urfa
# City not found. Skipping...
# Processing Record 50 of Set 15 | pafos
# Processing Record 1 of Set 16 | monrovia
# Processing Record 2 of Set 16 | raga
# Processing Record 3 of Set 16 | szubin
# Processing Record 4 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 16 | grand-santi
# Processing Record 6 of Set 16 | la ronge
# Processing Record 7 of Set 16 | acarau
# Processing Record 8 of Set 16 | ankpa
# Processing Record 9 of Set 16 | nouakchott
# Processing Record 10 of Set 16 | tavricheskoye
# Processing Record 11 of Set 16 | fraserburgh
# Processing Record 12 of Set 16 | auburn hills
# Processing Record 13 of Set 16 | christchurch
# Processing Record 14 of Set 16 | havoysund
# Processing Record 15 of Set 16 | kaduy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
#Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Komagane      JP  35.7296  137.9396     68.34        57          36
# 1  Severo-Kurilsk      RU  50.6789  156.1250     36.36        66          97
# 2         Ushuaia      AR -54.8000  -68.3000     40.66        81          40
# 3         Pathein      MM  16.7833   94.7333     87.12        65           6
# 4     East London      ZA -33.0153   27.9116     64.92        95         100
# 5    Punta Arenas      CL -53.1500  -70.9167     41.11        81          20
# 6        Hermanus      ZA -34.4187   19.2345     64.90        70          36
# 7     Yellowknife      CA  62.4560 -114.3525     24.42       100          90
# 8      Talcahuano      CL -36.7167  -73.1167     53.28        87           0
# 9         Mataura      NZ -46.1927  168.8643     63.37        64         100
#
#    Wind Speed Current Description
# 0        6.42    scattered clouds
# 1       23.71     overcast clouds
# 2        9.22    scattered clouds
# 3       11.05           clear sky
# 4        9.06       moderate rain
# 5        9.22          few clouds
# 6        4.29          light rain
# 7        6.91          light snow
# 8        8.05           clear sky
# 9        3.06     overcast clouds

# %%
#Export the DataFrame as a CSV file
export_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(export_file, index_label="City_ID")
